# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import tkinter as tk
from tkinter import filedialog 
from PIL import Image, ImageTk

# %%
train_dir =r'C:\Users\sushm\OneDrive\Desktop\AI and Green technologies training program\archive\train'
test_dir = r'C:\Users\sushm\OneDrive\Desktop\AI and Green technologies training program\archive\test'
valid_dir = r'C:\Users\sushm\OneDrive\Desktop\AI and Green technologies training program\archive\valid'

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir , target_size=(64,64), batch_size=32, class_mode='binary')
test_generator = test_datagen.flow_from_directory(test_dir , target_size=(64,64), batch_size=32, class_mode='binary')
valid_generator = valid_datagen.flow_from_directory(valid_dir , target_size=(64,64), batch_size=32, class_mode='binary')
# Out:
# Found 30250 images belonging to 2 classes.
# Found 6300 images belonging to 2 classes.
# Found 6300 images belonging to 2 classes.

# %%
model = Sequential([
    Conv2D(32,(3,3), activation='relu', input_shape=(64,64,3)),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(64,(3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1,activation='sigmoid')
    
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# C:\Users\sushm\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
history = model.fit(train_generator, validation_data = valid_generator , epochs=10, verbose=1)
# Out:
# C:\Users\sushm\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 1003s 1s/step - accuracy: 0.8456 - loss: 0.3209 - val_accuracy: 0.9435 - val_loss: 0.1547
# Epoch 2/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 627s 663ms/step - accuracy: 0.9332 - loss: 0.1843 - val_accuracy: 0.9440 - val_loss: 0.1469
# Epoch 3/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 136s 144ms/step - accuracy: 0.9383 - loss: 0.1645 - val_accuracy: 0.9506 - val_loss: 0.1332
# Epoch 4/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 120s 127ms/step - accuracy: 0.9422 - loss: 0.1541 - val_accuracy: 0.9467 - val_loss: 0.1365
# Epoch 5/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 80s 85ms/step - accuracy: 0.9479 - loss: 0.1369 - val_accuracy: 0.9475 - val_loss: 0.1420
# Epoch 6/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 78s 82ms/step - accuracy: 0.9534 - loss: 0.1239 - val_accuracy: 0.9537 - val_loss: 0.1303
# Epoch 7/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 78s 83ms/step - accuracy: 0.9586 - loss: 0.1129 - val_accuracy: 0.9617 - val_loss: 0.1077
# Epoch 8/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 78s 82ms/step - accuracy: 0.9604 - loss: 0.1076 - val_accuracy: 0.9638 - val_loss: 0.1014
# Epoch 9/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 77s 81ms/step - accuracy: 0.9643 - loss: 0.0967 - val_accuracy: 0.9483 - val_loss: 0.1533
# Epoch 10/10
# 946/946 ━━━━━━━━━━━━━━━━━━━━ 76s 80ms/step - accuracy: 0.9693 - loss: 0.0791 - val_accuracy: 0.9627 - val_loss: 0.1138
